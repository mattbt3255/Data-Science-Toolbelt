# %% [markdown]
# # Pandas

# %%
# Create Dataframe - CSV/Seaborn/HTML
import pandas as pd
import seaborn as sns

df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv') # CSV

df = sns.load_dataset('titanic') # Seaborn

df_html = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')[0]  # By default creates a list of tables

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Create Dataframe from Dictionary
import numpy as np
import pandas as pd
import seaborn as sns

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

row_labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=row_labels)

df
# Out:
#    age animal priority  visits
# a  2.5    cat      yes       1
# b  3.0    cat      yes       3
# c  0.5  snake       no       2
# d  NaN    dog      yes       3
# e  5.0    dog       no       2
# f  2.0    cat       no       3
# g  4.5  snake       no       1
# h  NaN    cat      yes       1
# i  7.0    dog       no       2
# j  3.0    dog       no       1

# %%
# Create DataFrame from List of Dictionaries
import numpy as np
import pandas as pd
import seaborn as sns

data = [{'A': 5, 'B': 7, 'C': 1, 'D': 5},
        {'A': 2, 'B': 8, 'C': 8, 'D': 6},
        {'A': 4, 'B': 0, 'C': 8, 'D': 8}]

pd.DataFrame(data)
# Out:
#    A  B  C  D
# 0  5  7  1  5
# 1  2  8  8  6
# 2  4  0  8  8

# %%
# Create DataFrame from list of lists
import pandas as pd

list_of_lists = [['Heading1', 'Heading2'], [1 , 2], [3, 4]]

pd.DataFrame(list_of_lists[1:],columns=list_of_lists[0])
# Out:
#    Heading1  Heading2
# 0         1         2
# 1         3         4

# %%
# Create Dictionary from DataFrame
import pandas as pd

dicty = {'col1': [1, 2],'col2': [0.5, 0.75]}

df = pd.DataFrame(dicty,index=['row1', 'row2'])

print(df)
print(df.to_dict())
# Out:
#       col1  col2
# row1     1  0.50
# row2     2  0.75
# {'col1': {'row1': 1, 'row2': 2}, 'col2': {'row1': 0.5, 'row2': 0.75}}

# %%
# Display Schema and Summary Data
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

head = df.head(10) # Top 10 rows of data
info = df.info() # Schema
describe = df.describe
shape = df.shape
columns = list(df.columns.values)
indexes = list(df.index.values)
columns_name = list(df.columns.names)
indexes_name = list(df.index.names)

head
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# ...

# %%
# Select Columns & Rows
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df[['survived','sex']] # Columns

df[0:10:2] # Rows (Start:Stop:Step)

df[['survived','sex']][0:10:2] # Columns and Rows
# Out:
#    survived     sex
# 0         0    male
# 2         1  female
# 4         0    male
# 6         0    male
# 8         1  female

# %%
# Filter via .loc - Simple
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df.loc[[1,2,3,4],['age','sex']]
# Out:
#     age     sex
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
# Filter via .loc - With Mask (more complicated filter on rows)
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

mask = (df.sex == 'male') & (df.age > 20)

df.loc[mask,['sex','age','pclass']].head() # All males over 20 and only return the columns sex, age, and pclass
# Out:
#      sex   age  pclass
# 0   male  22.0       3
# 4   male  35.0       3
# 6   male  54.0       1
# 13  male  39.0       3
# 20  male  35.0       2

# %%
# Filter via .iloc
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df.iloc[0:10:2,0:6:2] # Row, Column | Start:Stop:Step
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
# Return index value
import pandas as pd
import seaborn as sns

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data,index=labels)

df.index[[0,2,3]].tolist()
# Out:
# ['a', 'c', 'd']

# %%
# Add a column/row
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

# Add Column
df['new_column'] = range(891) # Insert at end of columns
df.insert(1,column='new_column_2',value=range(891)) # Insert at specific column number

# Add Row
df.loc[891,:] = df.loc[0,:] # Insert/Update at specific row
df = df.append(df.loc[0,:],ignore_index=True) # Insert at end of rows
df.loc[len(df),:] = df.loc[0,:] # Insert at end of rows

df.tail(5)
# Out:
#      survived  new_column_2  pclass   sex   age  sibsp  parch   fare embarked  \
# 889       1.0         889.0     1.0  male  26.0    0.0    0.0  30.00        C
# 890       0.0         890.0     3.0  male  32.0    0.0    0.0   7.75        Q
# 891       0.0           0.0     3.0  male  22.0    1.0    0.0   7.25        S
# 892       0.0           0.0     3.0  male  22.0    1.0    0.0   7.25        S
# 893       0.0           0.0     3.0  male  22.0    1.0    0.0   7.25        S
#
#      class  who  adult_male deck  embark_town alive  alone  new_column
# 889  First  man        True    C    Cherbourg   yes   True       889.0
# 890  Third  man        True  NaN   Queenstown    no   True       890.0
# 891  Third  man        True  NaN  Southampton    no  False         0.0
# 892  Third  man        True  NaN  Southampton    no  False         0.0
# 893  Third  man        True  NaN  Southampton    no  False         0.0

# %%
# Remove a column/row
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df.drop('survived',axis='columns',inplace=True) # Drop Column
df.drop(3,axis='rows',inplace=True) # Drop Row

df.head(5)
# Out:
#    pclass     sex   age  sibsp  parch     fare embarked  class    who  \
# 0       3    male  22.0      1      0   7.2500        S  Third    man
# 1       1  female  38.0      1      0  71.2833        C  First  woman
# 2       3  female  26.0      0      0   7.9250        S  Third  woman
# 4       3    male  35.0      0      0   8.0500        S  Third    man
# 5       3    male   NaN      0      0   8.4583        Q  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 4        True  NaN  Southampton    no   True
# 5        True  NaN   Queenstown    no   True

# %%
# Replace, Map, Where
import numpy as np
import pandas as pd
import seaborn as sns

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

row_labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=row_labels)

df['new_visits'] = df['visits'].replace(3,'three')
df['new_priority'] = df['priority'].map({'yes': 1,'no': 0})
df['new_animal'] = np.where(df['animal']=='snake','python','not_snake')

df
# Out:
#   animal  age  visits priority new_visits  new_priority new_animal
# a    cat  2.5       1      yes          1             1  not_snake
# b    cat  3.0       3      yes      three             1  not_snake
# c  snake  0.5       2       no          2             0     python
# d    dog  NaN       3      yes      three             1  not_snake
# e    dog  5.0       2       no          2             0  not_snake
# f    cat  2.0       3       no      three             0  not_snake
# g  snake  4.5       1       no          1             0     python
# h    cat  NaN       1      yes          1             1  not_snake
# i    dog  7.0       2       no          2             0  not_snake
# j    dog  3.0       1       no          1             0  not_snake

# %%
# Apply with Lambda
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df['age_doubled'] = df['age'].apply(lambda x: x * 2)

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_doubled
# 0    man        True  NaN  Southampton    no  False         44.0
# 1  woman       False    C    Cherbourg   yes  False         76.0
# 2  woman       False  NaN  Southampton   yes   True         52.0
# 3  woman       False    C  Southampton   yes  False         70.0
# 4    man        True  NaN  Southampton    no   True         70.0

# %%
# Apply with Custom Function
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

def custom_function(x):
    return x * 2

df['age_doubled'] = df['age'].apply(custom_function)

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_doubled
# 0    man        True  NaN  Southampton    no  False         44.0
# 1  woman       False    C    Cherbourg   yes  False         76.0
# 2  woman       False  NaN  Southampton   yes   True         52.0
# 3  woman       False    C  Southampton   yes  False         70.0
# 4    man        True  NaN  Southampton    no   True         70.0

# %%
# Sum, Min, Max, Len
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df['age'].sum()
df['age'].min()
df['age'].max()
len(df['age'])
# Out:
# 891

# %%
# Value Count
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
# Unique Values
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df['class'].nunique() # Returns # of unique values
df['class'].unique() # Returns unique values
# Out:
# 3

# %%
# Sort Values
import pandas as pd
import numpy as np

df = pd.DataFrame({'col1' : ['A', 'A', 'B', np.nan, 'D', 'C'],
                   'col2' : [2, 1, 9, 8, 7, 4],
                   'col3': [0, 1, 9, 4, 2, 3]})

df.sort_values(by=['col1', 'col2'],ascending=[True,False], na_position='first')
# Out:
#   col1  col2  col3
# 3  NaN     8     4
# 0    A     2     0
# 1    A     1     1
# 2    B     9     9
# 5    C     4     3
# 4    D     7     2

# %%
# Set/Reset Index
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df = df.set_index('fare')
df.reset_index(inplace=True)

df.head()
# Out:
#       fare  survived  pclass     sex   age  sibsp  parch embarked  class  \
# 0   7.2500         0       3    male  22.0      1      0        S  Third
# 1  71.2833         1       1  female  38.0      1      0        C  First
# 2   7.9250         1       3  female  26.0      0      0        S  Third
# 3  53.1000         1       1  female  35.0      1      0        S  First
# 4   8.0500         0       3    male  35.0      0      0        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Change Column/Index Names
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df.rename(index={0:"Zero",1:"One"},columns={"fare": "price", "sex": "gender"},inplace=True) # Replace with specific values

df.rename(columns=str.upper,inplace=True) # With function (can use lambda)

df.head()
# Out:
#       SURVIVED  PCLASS  GENDER   AGE  SIBSP  PARCH    PRICE EMBARKED  CLASS  \
# Zero         0       3    male  22.0      1      0   7.2500        S  Third
# One          1       1  female  38.0      1      0  71.2833        C  First
# 2            1       3  female  26.0      0      0   7.9250        S  Third
# 3            1       1  female  35.0      1      0  53.1000        S  First
# 4            0       3    male  35.0      0      0   8.0500        S  Third
#
#         WHO  ADULT_MALE DECK  EMBARK_TOWN ALIVE  ALONE
# Zero    man        True  NaN  Southampton    no  False
# One   woman       False    C    Cherbourg   yes  False
# 2     woman       False  NaN  Southampton   yes   True
# 3     woman       False    C  Southampton   yes  False
# 4       man        True  NaN  Southampton    no   True

# %%
# Change Title of Index
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df = df.rename_axis("index_name")

df.head()
# Out:
#             survived  pclass     sex   age  sibsp  parch     fare embarked  \
# index_name
# 0                  0       3    male  22.0      1      0   7.2500        S
# 1                  1       1  female  38.0      1      0  71.2833        C
# 2                  1       3  female  26.0      0      0   7.9250        S
# 3                  1       1  female  35.0      1      0  53.1000        S
# 4                  0       3    male  35.0      0      0   8.0500        S
#
#             class    who  adult_male deck  embark_town alive  alone
# index_name
# 0           Third    man        True  NaN  Southampton    no  False
# 1           First  woman       False    C    Cherbourg   yes  False
# 2           Third  woman       False  NaN  Southampton   yes   True
# 3           First  woman       False    C  Southampton   yes  False
# 4           Third    man        True  NaN  Southampton    no   True

# %%
# Change column to different type
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df['age'] = df['age'].astype(str)

df['age'].dtype
# Out:
# dtype('O')

# %%
# Between (inclusive on both ends)
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df['age'].between(20,30).head()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# Name: age, dtype: bool

# %%
# Split
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df['fare'].astype(str).str.split('.',expand=True)
# Out:
#       0     1
# 0     7    25
# 1    71  2833
# 2     7   925
# 3    53     1
# 4     8    05
# ..   ..   ...
# 886  13     0
# 887  30     0
# 888  23    45
# 889  30     0
# 890   7    75
#
# [891 rows x 2 columns]

# %%
# Assign (creates new columns)

import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df.assign(a='a',b='b')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
# Groupby on single column
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df.groupby('sex')['age'].describe()
df.groupby('sex')['age'].mean()

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Group by on multiple columns
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df.groupby(['sex','class'])['age'].mean()
# Out:
# sex     class
# female  First     34.611765
#         Second    28.722973
#         Third     21.750000
# male    First     41.281386
#         Second    30.740707
#         Third     26.507589
# Name: age, dtype: float64

# %%
# Pivot Table
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

df.pivot_table(values='age', index='sex', columns='class', aggfunc='mean', fill_value='No Age')
# Out:
# class       First     Second      Third
# sex
# female  34.611765  28.722973  21.750000
# male    41.281386  30.740707  26.507589

# %%
# Pivot Table - Slicing
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

pivot_table = df.pivot_table(values='age', index='sex', columns='class', aggfunc='mean', fill_value='No Age')

pivot_table.loc['female',['First','Second']]
# Out:
# class
# First     34.611765
# Second    28.722973
# Name: female, dtype: float64

# %%
# Unpivot a Pivot Table
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

pivot_table = df.pivot_table(values='age', index='sex', columns='class', aggfunc='mean', fill_value='No Age')

pivot_table.stack().reset_index(name='age')
# Out:
#       sex   class        age
# 0  female   First  34.611765
# 1  female  Second  28.722973
# 2  female   Third  21.750000
# 3    male   First  41.281386
# 4    male  Second  30.740707
# 5    male   Third  26.507589

# %%
# Melting 
import pandas as pd

df = pd.DataFrame([[2, 4, 7, 8, 1, 3, 2013], [9, 2, 4, 5, 5, 6, 2014]], columns=['Amy', 'Bob', 'Carl', 'Chris', 'Ben', 'Other', 'Year'])

print(df.head())
print(pd.melt(df, id_vars=['Year'], var_name='Name',value_name='Value').head())
# Out:
#    Amy  Bob  Carl  Chris  Ben  Other  Year
# 0    2    4     7      8    1      3  2013
# 1    9    2     4      5    5      6  2014
#    Year  Name  Value
# 0  2013   Amy      2
# 1  2014   Amy      9
# 2  2013   Bob      4
# 3  2014   Bob      2
# 4  2013  Carl      7

# %%
# Get Dummies (1 for every time it occurs)
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

pd.get_dummies(df['class'],drop_first=False).head() # Drop first means to drop the first column of dummies.
# Out:
#    First  Second  Third
# 0      0       0      1
# 1      1       0      0
# 2      0       0      1
# 3      1       0      0
# 4      0       0      1

# %%
# Drop Duplicates
import pandas as pd
import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 2.5, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 1, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

row_labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=row_labels)

df.drop_duplicates(keep='first') # Keep='first/last' means you the first/last index of the duplicate, Keep=False means you remove all duplicates.
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
# Find Duplicates
import pandas as pd
import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 2.5, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 1, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

row_labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=row_labels)

df.duplicated(keep=False)
# Out:
# a     True
# b     True
# c    False
# d    False
# e    False
# f    False
# g    False
# h    False
# i    False
# j    False
# dtype: bool

# %%
# Find Nulls
import pandas as pd
import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 2.5, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 1, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

row_labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=row_labels)

df.isnull()
# Out:
#      age  animal  priority  visits
# a  False   False     False   False
# b  False   False     False   False
# c  False   False     False   False
# d   True   False     False   False
# e  False   False     False   False
# f  False   False     False   False
# g  False   False     False   False
# h   True   False     False   False
# i  False   False     False   False
# j  False   False     False   False

# %%
# Drop Nulls
import pandas as pd
import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 2.5, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 1, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

row_labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=row_labels)

df.dropna(how='all') # how='all' makes it to where you only drop the row if all the columns have NA
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  2.5       1      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
# Replace Nulls (all nulls in data frame)
import pandas as pd
import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 2.5, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 1, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

row_labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=row_labels)

df = df.fillna('Filled',axis=1)

df
# Out:
#   animal     age  visits priority
# a    cat     2.5       1      yes
# b    cat     2.5       1      yes
# c  snake     0.5       2       no
# d    dog  Filled       3      yes
# e    dog       5       2       no
# f    cat       2       3       no
# g  snake     4.5       1       no
# h    cat  Filled       1      yes
# i    dog       7       2       no
# j    dog       3       1       no

# %%
# Replace Nulls (nulls for specific columns)
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 2.5, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 1, 2, 3, 2, 3, 1, 1,np.nan,np.nan],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

row_labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=row_labels)

df = df.fillna({'age':'filled'})

df
# Out:
#   animal     age  visits priority
# a    cat     2.5     1.0      yes
# b    cat     2.5     1.0      yes
# c  snake     0.5     2.0       no
# d    dog  filled     3.0      yes
# e    dog       5     2.0       no
# f    cat       2     3.0       no
# g  snake     4.5     1.0       no
# h    cat  filled     1.0      yes
# i    dog       7     NaN       no
# j    dog       3     NaN       no

# %%
# Shift data down (positive) or up (negative) a row (axis='index') or column (axis='columns')
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7],'B':list('abcefghijkl')})

print(df)
print(df.shift(periods=-1,axis='index')) # Shift Up
# Out:
#     A  B
# 0   1  a
# 1   2  b
# 2   2  c
# 3   3  e
# 4   4  f
# 5   5  g
# 6   5  h
# 7   5  i
# 8   6  j
# 9   7  k
# 10  7  l
#       A    B
# 0   2.0    b
# 1   2.0    c
# 2   3.0    e
# 3   4.0    f
# 4   5.0    g
# 5   5.0    h
# 6   5.0    i
# 7   6.0    j
# 8   7.0    k
# 9   7.0    l
# 10  NaN  NaN

# %%
# Sum/Mean/Max/Min entire row or column
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7],
                   'B':list('abcefghijkl'),
                   'C': [5, 10, 10, 15, 20, 25, 25, 25, 30, 35, 35]})

df.min(axis='columns',numeric_only=True)
# Out:
# 0     1
# 1     2
# 2     2
# 3     3
# 4     4
# 5     5
# 6     5
# 7     5
# 8     6
# 9     7
# 10    7
# dtype: int64

# %%
# Subtract/Add columns/rows from specified value
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7],
                   'C': [5, 10, 10, 15, 20, 25, 25, 25, 30, 35, 35]})

df.sub(1,axis='index')
df.add(1,axis='index')
# Out:
#     A   C
# 0   2   6
# 1   3  11
# 2   3  11
# 3   4  16
# 4   5  21
# 5   6  26
# 6   6  26
# 7   6  26
# 8   7  31
# 9   8  36
# 10  8  36

# %%
# Find columns that is the min or max
import pandas as pd

df = pd.DataFrame({'A': [5, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7],
                   'C': [1, 1, 10, 2, 20, 25, 25, 4, 30, 35, 35]})

df.idxmin(axis='columns') # Return the column name that has the least value
df.idxmax(axis='columns') # Return the column name that has the max value
# Out:
# 0     A
# 1     A
# 2     C
# 3     A
# 4     C
# 5     C
# 6     C
# 7     A
# 8     C
# 9     C
# 10    C
# dtype: object

# %%
# Find index that is the min or max
import pandas as pd

df = pd.DataFrame({'A': [5, 0, 2, 3, 4, 5, 5, 5, 6, 7, 7],
                   'C': [1, 1, 10, 2, 20, 25, 100, 4, 30, 35, 35]})

df['A'].idxmin(axis='index')
df['C'].idxmax(axis='index')
# Out:
# 6

# %%
# Return the biggest X number of values from a column
import pandas as pd

df = pd.DataFrame({'A': [5, 0, 2, 3, 4, 5, 5, 100, 200, 7, 7],
                   'C': [1, 1, 10, 2, 20, 25, 100, 4, 30, 35, 35]})

df['A'].nlargest(2)
# Out:
# 8    200
# 7    100
# Name: A, dtype: int64

# %%
# Concatination (add a dataframe to the bottom/right of another dataframe)
import pandas as pd

df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7]) 

pd.concat([df1,df2])
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
# Concatination (joining multiple dataframes on index)

df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])

df2 = pd.DataFrame({'E': ['A4', 'A5', 'A6', 'A7'],
                    'F': ['B4', 'B5', 'B6', 'B7'],
                    'G': ['C4', 'C5', 'C6', 'C7'],
                    'H': ['D4', 'D5', 'D6', 'D7']},
                   index=[0, 1, 2, 4]) 


pd.concat([df1,df2],axis='columns',join='outer')
# Out:
#      A    B    C    D    E    F    G    H
# 0   A0   B0   C0   D0   A4   B4   C4   D4
# 1   A1   B1   C1   D1   A5   B5   C5   D5
# 2   A2   B2   C2   D2   A6   B6   C6   D6
# 3   A3   B3   C3   D3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN   A7   B7   C7   D7

# %%
# Merging (similar to v-lookup/merging SQL tables based on unique value in column)
import pandas as pd

left = pd.DataFrame({'key1': ['K0', 'K1', 'K2', 'K3'],
                     'key2': ['K0', 'K0', 'K1', 'K2'],
                     'key3': ['K0', 'K1', 'K0', 'K1'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['K0', 'K1', 'K2', 'K3'],
                      'key2': ['K0', 'K1', 'K1', 'K2'],
                      'key3': ['K0', 'K0', 'K0', 'K0'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']})

df_merge1 = pd.merge(left,right,how='inner',left_on='key1',right_on='key1')  # Merging on single unique ID
df_merge2 = pd.merge(left,right,how='inner',on=['key1','key2']) # Merging on combination of two unique IDs

df_merge1
# Out:
#     A   B key1 key2_x key3_x   C   D key2_y key3_y
# 0  A0  B0   K0     K0     K0  C0  D0     K0     K0
# 1  A1  B1   K1     K0     K1  C1  D1     K1     K0
# 2  A2  B2   K2     K1     K0  C2  D2     K1     K0
# 3  A3  B3   K3     K2     K1  C3  D3     K2     K0

# %%
# Styling (https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html)
import pandas as pd
import numpy as np

# Build Dataframe
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan

# Create Conditional Function (highlight negative numbers red)
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: {}'.format(color)

# Apply Function
df.style.applymap(color_negative_red,subset=['B', 'C', 'D'])
# Out:
# <style  type="text/css" >
#     #T_b9fcc15a_2fef_11e9_b43f_6c4008a34822row0_col1 {
#             color:  red;
#         }    #T_b9fcc15a_2fef_11e9_b43f_6c4008a34822row0_col2 {
#             color:  black;
#         }    #T_b9fcc15a_2fef_11e9_b43f_6c4008a34822row0_col3 {
#             color:  black;
#         }    #T_b9fcc15a_2fef_11e9_b43f_6c4008a34822row1_col1 {
#             color:  black;
#         }    #T_b9fcc15a_2fef_11e9_b43f_6c4008a34822row1_col2 {
#             color:  black;
#         }    #T_b9fcc15a_2fef_11e9_b43f_6c4008a34822row1_col3 {
#             color:  black;
#         }    #T_b9fcc15a_2fef_11e9_b43f_6c4008a34822row2_col1 {
#             color:  black;
#         }    #T_b9fcc15a_2fef_11e9_b43f_6c4008a34822row2_col2 {
#             color:  black;
#         }    #T_b9fcc15a_2fef_11e9_b43f_6c4008a34822row2_col3 {
#             color:  red;
#         }    #T_b9fcc15a_2fef_11e9_b43f_6c4008a34822row3_col1 {
#             color:  red;
# ...

# %%
# .isin
import pandas as pd

df = pd.DataFrame({'num_legs': [2, 4], 'num_wings': [2, 0]},index=['falcon', 'dog'])

df.isin([0, 2]) # All columns
df.isin({'num_wings': [0, 3]}) # Single column
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog        False       True

# %%
# Creating Visualizations
import pandas as pd
import seaborn as sns

df = sns.load_dataset('flights')

# Scatterplot
df.plot.scatter(x='year',y='passengers',c='red',s=10)

# Barplot
df.plot.bar()

# Histogram
df['passengers'].plot.hist(bins=30)

# %%
# to_sql (Write records stored in a DataFrame to a SQL database.)

import pandas as pd
import seaborn as sns

df = sns.load_dataset('flights')

df.to_sql(name='database_name',
